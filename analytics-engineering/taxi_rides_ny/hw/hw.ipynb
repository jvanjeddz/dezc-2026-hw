# %%
import duckdb
import numpy
import pandas

conn = duckdb.connect('/app/taxi_rides_ny.duckdb')

# %%
# 3
result = conn.sql("SELECT COUNT(*) as record_count FROM prod.fct_monthly_zone_revenue").fetchone()
print(result[0])
# Out:
# 12184

# %%
# 4
result = conn.sql("""
    SELECT 
        pickup_zone,
        SUM(revenue_monthly_total_amount) as total_revenue
    FROM prod.fct_monthly_zone_revenue
    WHERE service_type = 'Green'
        AND EXTRACT(YEAR FROM revenue_month) = 2020
    GROUP BY pickup_zone
    ORDER BY total_revenue DESC
    LIMIT 1
""").fetchall()


print(result)
# Out:
# [('East Harlem North', Decimal('1817215.550'))]

# %%
# 5
result = conn.sql("""
    SELECT 
        sum(total_monthly_trips)
    FROM prod.fct_monthly_zone_revenue
    WHERE service_type = 'Green'
        AND EXTRACT (MONTH FROM revenue_month) = 10
        AND EXTRACT(YEAR FROM revenue_month) = 2019
""").show()
# Out:
# ┌──────────────────────────┐
# │ sum(total_monthly_trips) │
# │          int128          │
# ├──────────────────────────┤
# │                   384624 │
# └──────────────────────────┘

# %%
# 6
conn.sql("""
SELECT COUNT(*)
FROM prod.fhv_tripdata
""").show()
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │     43244696 │
# └──────────────┘
